# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df=pd.read_csv("/kaggle/input/datasets/iammustafatz/diabetes-prediction-dataset/diabetes_prediction_dataset.csv")
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.shape
# Out:
# (100000, 9)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  str
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  str
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), str(2)
# memory usage: 8.0 MB

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df['diabetes'].value_counts()
# 1 means positive and 0 means negative
# Out:
# diabetes
# 0    91500
# 1     8500
# Name: count, dtype: int64

# %%
df['diabetes'].value_counts().plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('Diabetes Value Counts')
plt.xlabel('Status')
plt.ylabel('Count')
plt.xticks(rotation=0) 
plt.show()

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    58552
# Male      41430
# Other        18
# Name: count, dtype: int64

# %%
df['gender'].value_counts().plot(kind='bar', color=['skyblue', 'salmon', 'seagreen'])
plt.title('Gender Value Counts')
plt.xlabel('Status')
plt.ylabel('Count')
plt.xticks(rotation=0) 
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='smoking_history', hue='diabetes', palette='Set2')
plt.title('Diabetes Status by Smoking History')
plt.xlabel('Smoking History')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
ax = sns.countplot(data=df, x='heart_disease', hue='diabetes', palette='coolwarm')
plt.xticks(ticks=[0, 1], labels=['No Heart Disease', 'Has Heart Disease'])
plt.title('Diabetes Distribution by Heart Disease Status')
# Out:
# Text(0.5, 1.0, 'Diabetes Distribution by Heart Disease Status')

# %%
plt.figure(figsize=(9, 5))
sns.kdeplot(data=df, x='age', hue='diabetes', fill=True, palette='Set1', common_norm=False)
plt.title('Age Distribution Patterns by Diabetes Status')
plt.xlabel('Age')
plt.ylabel('Density')
plt.legend(title='Diabetes', labels=['Has Diabetes (1)', 'No Diabetes (0)'])
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='gender', hue='diabetes', palette='Set2')
plt.title('Diabetes Patient Counts by Gender')
plt.xlabel('Gender')
plt.ylabel('Patient Count')
plt.legend(title='Diabetes', labels=['No (0)', 'Yes (1)'])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(9, 6))
sns.countplot(data=df, x='hypertension', hue='diabetes', palette='muted')
plt.title('Diabetes Counts grouped by Hypertension Status', fontsize=14, pad=15)
plt.xlabel('Hypertension Status', fontsize=12)
plt.ylabel('Number of Patients', fontsize=12)
plt.xticks(ticks=(0, 1), labels=['No Hypertension (0)', 'Has Hypertension (1)'])
plt.legend(title='Diabetes Status', labels=['No Diabetes (0)', 'Has Diabetes (1)'])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(9, 5))
sns.kdeplot(data=df, x='bmi', hue='diabetes', fill=True, palette='Set1', common_norm=False)
plt.title('BMI Distribution Patterns by Diabetes Status', fontsize=14, pad=15)
plt.xlabel('Body Mass Index (BMI)', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.legend(title='Diabetes Status', labels=['Has Diabetes (1)', 'No Diabetes (0)'])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(9, 5))
sns.kdeplot(data=df, x='blood_glucose_level', hue='diabetes', fill=True, palette='Set1', common_norm=False)
plt.title('Blood Glucose Level Distribution by Diabetes Status', fontsize=14, pad=15, fontweight='bold')
plt.xlabel('Blood Glucose Level (mg/dL)', fontsize=12)
plt.ylabel('Density (Relative Probability)', fontsize=12)
plt.legend(title='Diabetes Status', labels=['Has Diabetes (1)', 'No Diabetes (0)'])
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 5))

# Plot the average HbA1c level for each group
# hue='diabetes' and legend=False are included to prevent any console warnings
sns.barplot(
    data=df, 
    x='diabetes', 
    y='HbA1c_level', 
    hue='diabetes', 
    legend=False, 
    errorbar=None, 
    palette='rocket'
)

# Add explicit titles and labels
plt.title('Average HbA1c Level by Diabetes Status', fontsize=14, pad=15, fontweight='bold')
plt.xlabel('Diabetes Status', fontsize=12)
plt.ylabel('Average HbA1c Level (%)', fontsize=12)

# Change the X-axis numbers (0 and 1) to clear labels safely
plt.xticks(ticks=(0, 1), labels=['No Diabetes (0)', 'Has Diabetes (1)'])

plt.tight_layout()
plt.show()

# %%
df = pd.get_dummies(df, columns=['gender', 'smoking_history'], drop_first=True)
df.shape
# Out:
# (100000, 14)

# %%
from sklearn.model_selection import train_test_split

df_sample, _ = train_test_split(df, train_size=15000, stratify=df['diabetes'], random_state=42)
df_sample['diabetes'].value_counts()
# Out:
# diabetes
# 0    13725
# 1     1275
# Name: count, dtype: int64

# %%
X = df_sample.drop('diabetes', axis=1)
y = df_sample['diabetes']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
X_train.shape
# Out:
# (12000, 13)

# %%
y_train.value_counts()
# Out:
# diabetes
# 0    10980
# 1     1020
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

log_model = LogisticRegression()
log_model.fit(X_train_scaled, y_train)
y_pred_log = log_model.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

print(accuracy_score(y_test, y_pred_log))
print(confusion_matrix(y_test, y_pred_log))
print(classification_report(y_test, y_pred_log))
# Out:
# 0.9596666666666667
# [[2714   31]
#  [  90  165]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      2745
#            1       0.84      0.65      0.73       255
#
#     accuracy                           0.96      3000
#    macro avg       0.90      0.82      0.85      3000
# weighted avg       0.96      0.96      0.96      3000

# %%
log_acc = accuracy_score(y_test, y_pred_log)
log_report = classification_report(y_test, y_pred_log, output_dict=True)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train_scaled, y_train)
y_pred_knn = knn_model.predict(X_test_scaled)

# %%
print(accuracy_score(y_test, y_pred_knn))
print(confusion_matrix(y_test, y_pred_knn))
print(classification_report(y_test, y_pred_knn))

knn_acc = accuracy_score(y_test, y_pred_knn)
knn_report = classification_report(y_test, y_pred_knn, output_dict=True)
# Out:
# 0.954
# [[2721   24]
#  [ 114  141]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      2745
#            1       0.85      0.55      0.67       255
#
#     accuracy                           0.95      3000
#    macro avg       0.91      0.77      0.82      3000
# weighted avg       0.95      0.95      0.95      3000

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)

# %%
print(accuracy_score(y_test, y_pred_dt))
print(confusion_matrix(y_test, y_pred_dt))
print(classification_report(y_test, y_pred_dt))

dt_acc = accuracy_score(y_test, y_pred_dt)
dt_report = classification_report(y_test, y_pred_dt, output_dict=True)
# Out:
# 0.9483333333333334
# [[2658   87]
#  [  68  187]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97      2745
#            1       0.68      0.73      0.71       255
#
#     accuracy                           0.95      3000
#    macro avg       0.83      0.85      0.84      3000
# weighted avg       0.95      0.95      0.95      3000

# %%
from sklearn.naive_bayes import GaussianNB

nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
y_pred_nb = nb_model.predict(X_test)

# %%
print(accuracy_score(y_test, y_pred_nb))
print(confusion_matrix(y_test, y_pred_nb))
print(classification_report(y_test, y_pred_nb))

nb_acc = accuracy_score(y_test, y_pred_nb)
nb_report = classification_report(y_test, y_pred_nb, output_dict=True)
# Out:
# 0.8673333333333333
# [[2399  346]
#  [  52  203]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.87      0.92      2745
#            1       0.37      0.80      0.50       255
#
#     accuracy                           0.87      3000
#    macro avg       0.67      0.84      0.71      3000
# weighted avg       0.93      0.87      0.89      3000

# %%
from sklearn.svm import SVC

svm_model = SVC(kernel='linear')
svm_model.fit(X_train_scaled, y_train)
y_pred_svm = svm_model.predict(X_test_scaled)

# %%
print(accuracy_score(y_test, y_pred_svm))
print(confusion_matrix(y_test, y_pred_svm))
print(classification_report(y_test, y_pred_svm))

svm_acc = accuracy_score(y_test, y_pred_svm)
svm_report = classification_report(y_test, y_pred_svm, output_dict=True)
# Out:
# 0.9596666666666667
# [[2728   17]
#  [ 104  151]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      2745
#            1       0.90      0.59      0.71       255
#
#     accuracy                           0.96      3000
#    macro avg       0.93      0.79      0.85      3000
# weighted avg       0.96      0.96      0.96      3000

# %%
comparison_table = pd.DataFrame({
    'Model': ['Logistic Regression', 'KNN', 'Decision Tree', 'Naive Bayes', 'SVM'],
    'Accuracy': [log_acc, knn_acc, dt_acc, nb_acc, svm_acc],
    'Precision (diabetes)': [log_report['1']['precision'], knn_report['1']['precision'], dt_report['1']['precision'], nb_report['1']['precision'], svm_report['1']['precision']],
    'Recall (diabetes)': [log_report['1']['recall'], knn_report['1']['recall'], dt_report['1']['recall'], nb_report['1']['recall'], svm_report['1']['recall']],
    'F1-score (diabetes)': [log_report['1']['f1-score'], knn_report['1']['f1-score'], dt_report['1']['f1-score'], nb_report['1']['f1-score'], svm_report['1']['f1-score']]
})
comparison_table
# Out:
#                  Model  Accuracy  Precision (diabetes)  Recall (diabetes)  \
# 0  Logistic Regression  0.959667              0.841837           0.647059
# 1                  KNN  0.954000              0.854545           0.552941
# 2        Decision Tree  0.948333              0.682482           0.733333
# 3          Naive Bayes  0.867333              0.369763           0.796078
# 4                  SVM  0.959667              0.898810           0.592157
#
#    F1-score (diabetes)
# 0             0.731707
# 1             0.671429
# 2             0.706994
# 3             0.504975
# 4             0.713948

# %%
# Thus Logistic regression is the best suited model.

# %%
import pickle

# 1. Save the trained logistic regression model
with open('logistic_model.pkl', 'wb') as model_file:
    pickle.dump(log_model, model_file)  # Replace 'log_model' with your model's variable name

# 2. Save the fitted scaler
with open('scaler.pkl', 'wb') as scaler_file:
    pickle.dump(scaler, scaler_file)

print("Model and Scaler successfully saved!")
# Out:
# Model and Scaler successfully saved!
